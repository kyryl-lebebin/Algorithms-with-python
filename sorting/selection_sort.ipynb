# %%
import random
import matplotlib.pyplot as plt
import time



import sys
from pathlib import Path

# Add the parent directory to sys.path to allow for importing the `timing` module
parent_dir = str(Path.cwd().parent)
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

from timing.timeComp import quadratic

# %% [markdown]
# # Selection sort
# <video controls src="../media/selection.mp4" width="800">
#     Your browser does not support the video tag.
# </video>

# %%
def selection_sort(arr):
    # Traverse through all array elements
    for i in range(len(arr)):
        # Find the minimum element in remaining unsorted array
        min_idx = i
        for j in range(i+1, len(arr)):
            if arr[j] < arr[min_idx]:
                min_idx = j
                
        # Swap the found minimum element with the first element
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
        
    return arr

# %% [markdown]
# ## Time complexity
#
# - once you have first n-1 elements sorted, last is sorted as well
# - after ith iteration, positions 1-i contain i smallest elements in order
#
#
# **always case**: n-1 on first, n-2  on second, ... total: $\frac{n(n-1)}{2}$

# %%
@quadratic(n=int(input()))
def selection_sort(arr):
    # Traverse through all array elements
    for i in range(len(arr)):
        # Find the minimum element in remaining unsorted array
        min_idx = i
        for j in range(i+1, len(arr)):
            if arr[j] < arr[min_idx]:
                min_idx = j
                
        # Swap the found minimum element with the first element
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
        
    return arr

selection_sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 16
#      12         arr[i], arr[min_idx] = arr[min_idx], arr[i]
#      14     return arr
# ---> 16 selection_sort()
#
# File c:\Users\deryl\Projects\algorithms_py\timing\timeComp.py:52, in quadratic.<locals>.decorator.<locals>.wrapper()
#      49 plt.grid(True)
#      50 plt.show()
# ---> 52 return func()
#
# TypeError: selection_sort() missing 1 required positional argument: 'arr'
